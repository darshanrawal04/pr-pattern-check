# %%
{
 "cells": [
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "from delta.tables import DeltaTable\n",
    "DeltaTable.forPath(spark, \"/mnt/secrets\")\n"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 2
}
